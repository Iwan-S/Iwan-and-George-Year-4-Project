# %% [markdown]
# # 2D Gaussian Mixture Model
# ****

# %%
import corner
from dynesty import NestedSampler, utils
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import seaborn as sns

# %%
#%matplotlib notebook
π = np.pi

# %%
μ = [2, 5]
σ = [1, 2]
Σ = np.diag(σ)
Data = np.random.multivariate_normal(μ, Σ, size=2000)

# %%
plt.figure()
plt.plot(Data[:, 0], Data[:, 1], '.', markersize=2)
plt.show()

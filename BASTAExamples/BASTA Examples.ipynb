# %% [markdown]
# # BASTA Examples

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib notebook

# %%
Directory = 'C:/Users/georg/Documents/Homework/University/BASTAExamples'

# %%
def ScreamExtractor(Folder):
    return np.genfromtxt(f'{Directory}/{Folder}/results.ascii', dtype='str')

# %%
Global = ScreamExtractor('Global')
Freqs = ScreamExtractor('Freqs')

# %%
plt.figure()
plt.bar(0, float(Global[1]), color='blue')
plt.bar(0.8, float(Freqs[1]), color='green')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

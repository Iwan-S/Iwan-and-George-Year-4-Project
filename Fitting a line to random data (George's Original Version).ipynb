# %% [markdown]
# # Bayesianness

# %% [markdown]
# Importing the necessary modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit, minimize

# %%
# %matplotlib notebook

# %% [markdown]
# Code used to fit a model to data I nicked from a previous bit of work I did.

# %%
def Model(x, m, c):
    return m*x + c

# %% [markdown]
# Minimises the difference between data and model while varying m & c.

# %%
def MinimiseM(m, X, Y, c):
    Total = 0
    for n in range(len(X)):
        Total += (Y[n] - Model(X[n], m, c))**2
    return Total

def MinimiseC(c, X, Y, m):
    Total = 0
    for n in range(len(X)):
        Total += (Y[n] - Model(X[n], m, c))**2
    return Total

# %% [markdown]
# No idea what I'm doing here, lad, ngl.

# %%
def Likelihood(X, Y):
    print('Poo')

# %% [markdown]
# Creating a random set of numbers normally distributed and inputting it into y. A model is then created for this set of data.

# %%
x = np.random.randn(20)
m, c = 2, 3
noise = np.random.randn(20)
y = Model(x, m, c + noise)

# %% [markdown]
# Returns the best fit for m and c and then creates a best fitting line.

# %%
M = minimize(MinimiseM, 0, args=(x, y, c)).x
C = minimize(MinimiseC, 0, args=(x, y, m)).x
YModel = Model(x, M, C)

# %% [markdown]
# Find the errors on the parameters using Likelihood??

# %%
Likelihood(x, y)
# Out:
# Poo

# %%
print(f'M = {round(M[0], 3)}\nC = {round(C[0], 3)}')
# Out:
# M = 2.295
# C = 2.935

# %%
plt.figure()
plt.plot(x, y, '.', label='Normally Distributed Data')
plt.plot(x, YModel, label='Model for Data')
plt.title('Fitting a Straight Line to Data')
plt.xlabel('x')
plt.ylabel('y = f(x)')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# What are you looking at?
